# %%
from deimkit.exporter import Exporter
from deimkit.config import Config

config = Config("/home/dnth/Desktop/DEIMKit/outputs/rock-paper-scissors/deim_hgnetv2_s_30ep_640px_num_queries_100/config.yml")
exporter = Exporter(config)

output_path = exporter.to_onnx(
    checkpoint_path="/home/dnth/Desktop/DEIMKit/outputs/rock-paper-scissors/deim_hgnetv2_s_30ep_640px_num_queries_100_lr_gamma_0.1/best.pth",
    output_path="/home/dnth/Desktop/DEIMKit/outputs/rock-paper-scissors/deim_hgnetv2_s_30ep_640px_num_queries_100_lr_gamma_0.1/best_prep.onnx",
    include_preprocessing=True
)
# Out:
# 2025-03-31 10:35:25.954 | INFO     | deimkit.exporter:to_onnx:123 - Using device: cpu
# 2025-03-31 10:35:25.955 | INFO     | deimkit.exporter:to_onnx:126 - Loading checkpoint from /home/dnth/Desktop/DEIMKit/outputs/rock-paper-scissors/deim_hgnetv2_s_30ep_640px_num_queries_100_lr_gamma_0.1/best.pth
# 2025-03-31 10:35:26.278 | INFO     | deimkit.exporter:to_onnx:131 - Using EMA weights for model export
# 2025-03-31 10:35:26.461 | INFO     | deimkit.exporter:to_onnx:162 - Input shape not provided, getting size from config
# 2025-03-31 10:35:26.461 | INFO     | deimkit.exporter:to_onnx:188 - Using target shape from config: (1, 3, 640, 640)
# 2025-03-31 10:35:26.462 | INFO     | deimkit.exporter:__init__:32 - Initialized PreprocessingModule with target size: (640, 640)
# 2025-03-31 10:35:26.462 | INFO     | deimkit.exporter:to_onnx:201 - Including preprocessing steps in the ONNX model.
# 2025-03-31 10:35:26.474 | INFO     | deimkit.exporter:to_onnx:260 - Using input names: ['input_bgr', 'orig_target_sizes']
# 2025-03-31 10:35:26.475 | INFO     | deimkit.exporter:to_onnx:261 - Using output names: ['labels', 'boxes', 'scores']
# 2025-03-31 10:35:26.475 | INFO     | deimkit.exporter:to_onnx:262 - Using dynamic axes: {'input_bgr': {0: 'N', 2: 'H', 3: 'W'}, 'orig_target_sizes': {0: 'N'}, 'labels': {0: 'N'}, 'boxes': {0: 'N'}, 'scores': {0: 'N'}}
# 2025-03-31 10:35:26.476 | INFO     | deimkit.exporter:to_onnx:263 - Exporting model to ONNX: /home/dnth/Desktop/DEIMKit/outputs/rock-paper-scissors/deim_hgnetv2_s_30ep_640px_num_queries_100_lr_gamma_0.1/best_prep.onnx
# 2025-03-31 10:35:26.486 | DEBUG    | deimkit.exporter:forward:54 - Preprocessing: Resized shape: torch.Size([1, 3, 640, 640])
# /home/dnth/Desktop/DEIMKit/src/deimkit/exporter.py:58: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if x.shape[1] != 3:
# 2025-03-31 10:35:26.491 | DEBUG    | deimkit.exporter:forward:62 - Preprocessing: Swapped BGR to RGB
# 2025-03-31 10:35:26.493 | DEBUG    | deimkit.exporter:forward:67 - Preprocessing: Normalized pixel values to [0, 1]
# Loaded stage1 B0 HGNetV2 from local file.
# /home/dnth/Desktop/DEIMKit/src/deimkit/engine/deim/dfine_decoder.py:646: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if memory.shape[0] > 1:
# /home/dnth/Desktop/DEIMKit/src/deimkit/engine/deim/dfine_decoder.py:129: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if reference_points.shape[-1] == 2:
# /home/dnth/Desktop/DEIMKit/src/deimkit/engine/deim/dfine_decoder.py:133: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   elif reference_points.shape[-1] == 4:
# /home/dnth/Desktop/DEIMKit/.pixi/envs/cuda/lib/python3.11/site-packages/torch/onnx/_internal/jit_utils.py:308: UserWarning: Constant folding - Only steps=1 can be constant folded for opset >= 10 onnx::Slice op. Constant folding not applied. (Triggered internally at /pytorch/torch/csrc/jit/passes/onnx/constant_fold.cpp:178.)
#   _C._jit_pass_onnx_node_shape_type_inference(node, params_dict, opset_version)
# /home/dnth/Desktop/DEIMKit/.pixi/envs/cuda/lib/python3.11/site-packages/torch/onnx/utils.py:657: UserWarning: Constant folding - Only steps=1 can be constant folded for opset >= 10 onnx::Slice op. Constant folding not applied. (Triggered internally at /pytorch/torch/csrc/jit/passes/onnx/constant_fold.cpp:178.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# /home/dnth/Desktop/DEIMKit/.pixi/envs/cuda/lib/python3.11/site-packages/torch/onnx/utils.py:1127: UserWarning: Constant folding - Only steps=1 can be constant folded for opset >= 10 onnx::Slice op. Constant folding not applied. (Triggered internally at /pytorch/torch/csrc/jit/passes/onnx/constant_fold.cpp:178.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# 2025-03-31 10:35:28.011 | SUCCESS  | deimkit.exporter:to_onnx:285 - ONNX export completed successfully: /home/dnth/Desktop/DEIMKit/outputs/rock-paper-scissors/deim_hgnetv2_s_30ep_640px_num_queries_100_lr_gamma_0.1/best_prep.onnx
# 2025-03-31 10:35:28.011 | INFO     | deimkit.exporter:to_onnx:296 - Simplifying ONNX model with input shapes: {'input_bgr': torch.Size([1, 3, 640, 640]), 'orig_target_sizes': torch.Size([1, 2])}
# 2025-03-31 10:35:28.050 | INFO     | deimkit.exporter:_simplify_onnx_model:401 - Simplifying ONNX model: /home/dnth/Desktop/DEIMKit/outputs/rock-paper-scissors/deim_hgnetv2_s_30ep_640px_num_queries_100_lr_gamma_0.1/best_prep.onnx -> /home/dnth/Desktop/DEIMKit/outputs/rock-paper-scissors/deim_hgnetv2_s_30ep_640px_num_queries_100_lr_gamma_0.1/best_prep.onnx
# 2025-03-31 10:35:30.128 | SUCCESS  | deimkit.exporter:_simplify_onnx_model:411 - ONNX model simplification successful: /home/dnth/Desktop/DEIMKit/outputs/rock-paper-scissors/deim_hgnetv2_s_30ep_640px_num_queries_100_lr_gamma_0.1/best_prep.onnx
# 2025-03-31 10:35:30.207 | INFO     | deimkit.exporter:_check_onnx_model:368 - ONNX model validation successful: /home/dnth/Desktop/DEIMKit/outputs/rock-paper-scissors/deim_hgnetv2_s_30ep_640px_num_queries_100_lr_gamma_0.1/best_prep.onnx
