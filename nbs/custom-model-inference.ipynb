# %%
from deimkit import list_models, load_model

# %%
list_models()
# Out:
# ['deim_hgnetv2_n',
#  'deim_hgnetv2_s',
#  'deim_hgnetv2_m',
#  'deim_hgnetv2_l',
#  'deim_hgnetv2_x']

# %%
model = load_model("deim_hgnetv2_s", 
                   checkpoint="/home/dnth/Desktop/deim-wrapper/outputs/deim_hgnetv2_s_coco_cells/last.pth",
                   class_names=["cell", "platelet", "red_blood_cell", "white_blood_cell"])
# Out:
# 2025-03-10 12:27:16.403 | INFO     | deimkit.predictor:__init__:41 - Initializing Predictor with device=auto
# 2025-03-10 12:27:16.459 | INFO     | deimkit.predictor:__init__:60 - Auto-selected device: cuda
# 2025-03-10 12:27:16.459 | INFO     | deimkit.predictor:__init__:68 - Using custom checkpoint: /home/dnth/Desktop/deim-wrapper/outputs/deim_hgnetv2_s_coco_cells/last.pth
# 2025-03-10 12:27:16.462 | DEBUG    | deimkit.predictor:__init__:90 - Successfully initialized distributed environment
# 2025-03-10 12:27:16.462 | INFO     | deimkit.predictor:__init__:101 - Loading configuration from model name: deim_hgnetv2_s
# 2025-03-10 12:27:16.808 | WARNING  | deimkit.predictor:__init__:122 - Could not load checkpoint with non-strict loading: Error(s) in loading state_dict for DEIM:
# 	size mismatch for decoder.denoising_class_embed.weight: copying a param with shape torch.Size([5, 256]) from checkpoint, the shape in current model is torch.Size([81, 256]).
# 	size mismatch for decoder.enc_score_head.weight: copying a param with shape torch.Size([4, 256]) from checkpoint, the shape in current model is torch.Size([80, 256]).
# 	size mismatch for decoder.enc_score_head.bias: copying a param with shape torch.Size([4]) from checkpoint, the shape in current model is torch.Size([80]).
# 	size mismatch for decoder.dec_score_head.0.weight: copying a param with shape torch.Size([4, 256]) from checkpoint, the shape in current model is torch.Size([80, 256]).
# 	size mismatch for decoder.dec_score_head.0.bias: copying a param with shape torch.Size([4]) from checkpoint, the shape in current model is torch.Size([80]).
# 	size mismatch for decoder.dec_score_head.1.weight: copying a param with shape torch.Size([4, 256]) from checkpoint, the shape in current model is torch.Size([80, 256]).
# 	size mismatch for decoder.dec_score_head.1.bias: copying a param with shape torch.Size([4]) from checkpoint, the shape in current model is torch.Size([80]).
# 	size mismatch for decoder.dec_score_head.2.weight: copying a param with shape torch.Size([4, 256]) from checkpoint, the shape in current model is torch.Size([80, 256]).
# 	size mismatch for decoder.dec_score_head.2.bias: copying a param with shape torch.Size([4]) from checkpoint, the shape in current model is torch.Size([80]).
# 2025-03-10 12:27:16.808 | WARNING  | deimkit.predictor:__init__:123 - Attempting to adapt parameters with shape mismatches...
# 2025-03-10 12:27:16.811 | INFO     | deimkit.predictor:__init__:143 - Adapting parameter decoder.denoising_class_embed.weight: torch.Size([5, 256]) -> torch.Size([81, 256])
# 2025-03-10 12:27:16.812 | INFO     | deimkit.predictor:__init__:143 - Adapting parameter decoder.enc_score_head.weight: torch.Size([4, 256]) -> torch.Size([80, 256])
# 2025-03-10 12:27:16.812 | INFO     | deimkit.predictor:__init__:165 - Adapting parameter decoder.enc_score_head.bias: torch.Size([4]) -> torch.Size([80])
# 2025-03-10 12:27:16.813 | INFO     | deimkit.predictor:__init__:143 - Adapting parameter decoder.dec_score_head.0.weight: torch.Size([4, 256]) -> torch.Size([80, 256])
# 2025-03-10 12:27:16.813 | INFO     | deimkit.predictor:__init__:165 - Adapting parameter decoder.dec_score_head.0.bias: torch.Size([4]) -> torch.Size([80])
# 2025-03-10 12:27:16.814 | INFO     | deimkit.predictor:__init__:143 - Adapting parameter decoder.dec_score_head.1.weight: torch.Size([4, 256]) -> torch.Size([80, 256])
# 2025-03-10 12:27:16.814 | INFO     | deimkit.predictor:__init__:165 - Adapting parameter decoder.dec_score_head.1.bias: torch.Size([4]) -> torch.Size([80])
# 2025-03-10 12:27:16.814 | INFO     | deimkit.predictor:__init__:143 - Adapting parameter decoder.dec_score_head.2.weight: torch.Size([4, 256]) -> torch.Size([80, 256])
# 2025-03-10 12:27:16.815 | INFO     | deimkit.predictor:__init__:165 - Adapting parameter decoder.dec_score_head.2.bias: torch.Size([4]) -> torch.Size([80])
# 2025-03-10 12:27:16.832 | INFO     | deimkit.predictor:__init__:178 - Loaded 794/794 parameters from checkpoint (with adaptations)
# 2025-03-10 12:27:17.020 | SUCCESS  | deimkit.predictor:__init__:215 - Predictor initialization complete

# %%
result = model.predict("/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00099_jpg.rf.d60344d65fdf49563ec54664b0e79f70.jpg", 
                       visualize=True)
# Out:
# 2025-03-10 12:27:17.036 | DEBUG    | deimkit.predictor:predict:260 - Loading image from path: /home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00099_jpg.rf.d60344d65fdf49563ec54664b0e79f70.jpg
# 2025-03-10 12:27:17.379 | DEBUG    | deimkit.predictor:predict:300 - Prediction complete. Found 14 objects
# 2025-03-10 12:27:17.379 | DEBUG    | deimkit.predictor:predict:303 - Generating visualization

# %%
result
# Out:
# {'boxes': array([[218.09384  , 227.55255  , 375.73285  , 344.7434   ],
#         [430.8386   ,  16.011776 , 537.1694   , 116.61561  ],
#         [503.917    , 123.87391  , 616.61035  , 236.88312  ],
#         [541.34863  , 366.26514  , 638.21814  , 462.9139   ],
#         [384.67758  ,  63.953003 , 421.1351   , 101.81781  ],
#         [142.81082  , 156.13432  , 257.49286  , 247.55264  ],
#         [ 30.51321  ,   0.6768894, 135.71454  ,  79.99556  ],
#         [376.30585  , 187.7282   , 478.05756  , 288.92554  ],
#         [378.5854   , 405.62885  , 497.10324  , 480.16223  ],
#         [535.1882   ,   1.3033605, 634.80695  ,  79.057556 ],
#         [ 48.051674 , 318.62503  , 139.61072  , 418.04895  ],
#         [124.88125  , 215.90515  , 222.04155  , 325.52798  ],
#         [334.55652  , 151.38608  , 368.70123  , 186.04846  ],
#         [  1.058774 , 226.89442  ,  50.568428 , 334.1957   ]],
#        dtype=float32),
#  'labels': array([3, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 1, 2]),
#  'scores': array([0.828803  , 0.7779632 , 0.72461736, 0.69647616, 0.66181886,
#         0.6484041 , 0.6305612 , 0.5768298 , 0.48248014, 0.46841875,
#         0.34882692, 0.34398836, 0.31935868, 0.31776163], dtype=float32),
#  'class_names': ['white_blood_cell',
#   'red_blood_cell',
#   'red_blood_cell',
#   'red_blood_cell',
#   'platelet',
#   'red_blood_cell',
#   'red_blood_cell',
#   'red_blood_cell',
#   'red_blood_cell',
#   'red_blood_cell',
#   'red_blood_cell',
#   'red_blood_cell',
#   'platelet',
#   'red_blood_cell'],
#  'visualization': <PIL.Image.Image image mode=RGB size=640x480>}

# %%
result["visualization"]
# Out:
# <PIL.Image.Image image mode=RGB size=640x480>

# %%
# Load folder of images
import glob
image_paths = glob.glob('/home/dnth/Desktop/DEIM/dataset/images/test/*.jpg')

image_paths
# Out:
# ['/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00062_jpg.rf.d5f527bc75eb023b530cc25a76268d64.jpg',
#  '/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00254_jpg.rf.6766c79666f2bde5d4b5bbd988714a9e.jpg',
#  '/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00044_jpg.rf.76fca35f8f8f8310472b33f2fce3013a.jpg',
#  '/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00134_jpg.rf.dc3431fd875fa36eafd1e72c6218d691.jpg',
#  '/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00090_jpg.rf.2e7c0319b7e86fb52acc2e425148eb58.jpg',
#  '/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00302_jpg.rf.73c92ceaf01fd6a97da8c9653ee4b0e2.jpg',
#  '/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00120_jpg.rf.148c37b4a13a538157509f006b83b843.jpg',
#  '/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00266_jpg.rf.7ecb7f28fd7c45a4f129443425e1dd9b.jpg',
#  '/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00369_jpg.rf.86fbe6c7bdf7777bfb56e3960016c15d.jpg',
#  '/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00160_jpg.rf.fd4d096b1edd8e549d1268d4d531bb36.jpg',
#  '/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00301_jpg.rf.17cc710ee18f1332c4b7969b7e17c367.jpg',
#  '/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00325_jpg.rf.a194d881251b8e2dc22136e86e6314af.jpg',
#  '/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00154_jpg.rf.8dbf71af1f498cf17572b7ff0286ea38.jpg',
#  '/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00241_jpg.rf.d9285ace4f17f9e2aadc5a3f114ec182.jpg',
#  '/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00112_jpg.rf.7fd899f64e0ad1521c02d9316223382a.jpg',
#  '/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00334_jpg.rf.a587f3699c40c2a97cb412c27027576a.jpg',
#  '/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00289_jpg.rf.bfaa0cc70a9cc174d5feca646061ada0.jpg',
#  '/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00204_jpg.rf.2df6a9acbd4a99d998ede5b9e71c6795.jpg',
#  '/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00190_jpg.rf.c60cfea8c3ff7752e8776cd9a607cf53.jpg',
#  '/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00038_jpg.rf.c23bbdee6c919fc4cbe4ac99809b45dc.jpg',
#  '/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00227_jpg.rf.102fa7a2365b510d790e4b62f75e93f4.jpg',
#  '/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00113_jpg.rf.e85916dcff47d6471b18408ec7a33b8e.jpg',
#  '/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00235_jpg.rf.ca8404acb49765618a454a0f0ad6380f.jpg',
#  '/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00275_jpg.rf.b11d32f032df6b0f617f211e5ccc5a8a.jpg',
#  '/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00336_jpg.rf.77b6f69ccce10183b556b769f3179105.jpg',
#  '/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00386_jpg.rf.dd32235a2e482625fd1b383b3cd45f83.jpg',
#  '/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00284_jpg.rf.01c88664d931d0bd2249bc43b1e326fe.jpg',
#  '/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00385_jpg.rf.aeabacfab14a76b6e690931175397d0e.jpg',
#  '/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00099_jpg.rf.d60344d65fdf49563ec54664b0e79f70.jpg',
#  '/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00133_jpg.rf.f628ac399854563199e01c71bb4c47b7.jpg',
#  '/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00337_jpg.rf.858c1bc83e8f3c2ce00cf8c9727e7fd3.jpg',
#  '/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00265_jpg.rf.ced81733d22893ed479e80b1a2177698.jpg',
#  '/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00191_jpg.rf.04d7bdb4dac607d63244c9ab063d2114.jpg',
#  '/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00350_jpg.rf.d13e269d70e8c3261856a94b59351314.jpg',
#  '/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00278_jpg.rf.68bedb7b8477572342ce18aae05d25a3.jpg',
#  '/home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00359_jpg.rf.91084cab04c2579951c2af8531d1f41b.jpg']

# %%
results = model.predict_batch(image_paths[0:6], conf_threshold=0.2, visualize=True)
# Out:
# 2025-03-10 12:27:17.454 | INFO     | deimkit.predictor:predict_batch:338 - Processing batch of 6 images with batch_size=16
# 2025-03-10 12:27:17.455 | DEBUG    | deimkit.predictor:predict_batch:351 - Loading image 0 from path: /home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00062_jpg.rf.d5f527bc75eb023b530cc25a76268d64.jpg
# 2025-03-10 12:27:17.492 | DEBUG    | deimkit.predictor:predict_batch:351 - Loading image 1 from path: /home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00254_jpg.rf.6766c79666f2bde5d4b5bbd988714a9e.jpg
# 2025-03-10 12:27:17.500 | DEBUG    | deimkit.predictor:predict_batch:351 - Loading image 2 from path: /home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00044_jpg.rf.76fca35f8f8f8310472b33f2fce3013a.jpg
# 2025-03-10 12:27:17.509 | DEBUG    | deimkit.predictor:predict_batch:351 - Loading image 3 from path: /home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00134_jpg.rf.dc3431fd875fa36eafd1e72c6218d691.jpg
# 2025-03-10 12:27:17.516 | DEBUG    | deimkit.predictor:predict_batch:351 - Loading image 4 from path: /home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00090_jpg.rf.2e7c0319b7e86fb52acc2e425148eb58.jpg
# 2025-03-10 12:27:17.523 | DEBUG    | deimkit.predictor:predict_batch:351 - Loading image 5 from path: /home/dnth/Desktop/DEIM/dataset/images/test/BloodImage_00302_jpg.rf.73c92ceaf01fd6a97da8c9653ee4b0e2.jpg
# 2025-03-10 12:27:17.531 | DEBUG    | deimkit.predictor:predict_batch:368 - Processing batch of 6 images
# 2025-03-10 12:27:17.606 | DEBUG    | deimkit.predictor:predict_batch:393 - Generating visualization for image 0
# 2025-03-10 12:27:17.608 | DEBUG    | deimkit.predictor:predict_batch:393 - Generating visualization for image 1
# 2025-03-10 12:27:17.610 | DEBUG    | deimkit.predictor:predict_batch:393 - Generating visualization for image 2
# 2025-03-10 12:27:17.612 | DEBUG    | deimkit.predictor:predict_batch:393 - Generating visualization for image 3
# 2025-03-10 12:27:17.614 | DEBUG    | deimkit.predictor:predict_batch:393 - Generating visualization for image 4
# 2025-03-10 12:27:17.617 | DEBUG    | deimkit.predictor:predict_batch:393 - Generating visualization for image 5
# 2025-03-10 12:27:17.619 | SUCCESS  | deimkit.predictor:predict_batch:427 - Batch processing complete. Processed 6 images

# %%
# Plot results in a grid
import matplotlib.pyplot as plt
import math

n_cols = 2
n_rows = math.ceil(len(results) / n_cols)
plt.figure(figsize=(12, 4*n_rows))  

for i, result in enumerate(results):
    plt.subplot(n_rows, n_cols, i + 1)
    plt.imshow(result["visualization"])
    plt.axis('off')
plt.tight_layout()  
plt.show()
